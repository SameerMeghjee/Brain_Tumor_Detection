# %%
import zipfile
import os

zip_path = '/content/Tumor Detection.v8i.yolov11.zip'
extract_path = '/content/Brain_Tumor_Dataset'
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
print(f"✅ Extracted dataset to {extract_path}")
# Out:
# ✅ Extracted dataset to /content/Brain_Tumor_Dataset

# %%
# !pip install ultralytics
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="Brain_Tumor_Dataset/data.yaml",  # path to dataset YAML
    epochs=20,
    imgsz=640,
    device=0,
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Load a model
model = YOLO("runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("glioma_2.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/glioma_2.jpg: 640x640 2 gliomas, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results = model("no_tumor_1.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/no_tumor_1.jpg: 640x640 1 NO_tumor, 15.7ms
# Speed: 2.8ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# Load a model
model = YOLO("runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("glioma_2.jpg", save=True)
# Out:
# image 1/1 /content/glioma_2.jpg: 640x640 2 gliomas, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# Run batched inference on a list of images
results = model("glioma_2.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 /content/glioma_2.jpg: 640x640 2 gliomas, 18.0ms
# Speed: 2.5ms preprocess, 18.0ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 1.], device='cuda:0')
# conf: tensor([0.6629, 0.2778], device='cuda:0')
# data: tensor([[2.7335e+02, 4.2092e+02, 3.1479e+02, 4.4460e+02, 6.6288e-01, 1.0000e+00],
#         [4.3352e+02, 4.4463e+02, 4.6244e+02, 4.7030e+02, 2.7775e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([2, 6])
# xywh: tensor([[294.0658, 432.7577,  41.4414,  23.6781],
#         [447.9805, 457.4642,  28.9252,  25.6624]], device='cuda:0')
# xywhn: tensor([[0.4595, 0.6762, 0.0648, 0.0370],
#         [0.7000, 0.7148, 0.0452, 0.0401]], device='cuda:0')
# xyxy: tensor([[273.3451, 420.9186, 314.7865, 444.5967],
#         [433.5179, 444.6330, 462.4431, 470.2954]], device='cuda:0')
# ...

# %%
from ultralytics import SAM

yolo_model = YOLO("runs/detect/train/weights/best.pt")

# Run batched inference on a list of images
results = yolo_model("glioma_2.jpg")

# Load the SAM model
sam_model = SAM("sam2_b.pt")

for result in results:
     class_ids = result.boxes.cls.int().tolist()
     if len(class_ids):
         boxes = result.boxes.xyxy
         sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False, save=True, device=0)
# Out:
# image 1/1 /content/glioma_2.jpg: 640x640 2 gliomas, 27.6ms
# Speed: 5.1ms preprocess, 27.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# ...
# 100%|██████████| 154M/154M [00:00<00:00, 302MB/s]
# Results saved to runs/segment/predict
